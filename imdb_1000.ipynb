# %%
import numpy as np
import pandas as pd 

import requests 
from bs4 import BeautifulSoup

# %%
url = 'https://www.imdb.com/search/title/?count=100&groups=top_1000&sort=user_rating%27'

# %%
page = requests.get(url)

# %%
page.status_code
# Out:
# 200

# %%
htmlcode = page.text

# %%
htmlcode
# Out:
# '\n\n<!DOCTYPE html>\n<html\n    xmlns:og="http://ogp.me/ns#"\n    xmlns:fb="http://www.facebook.com/2008/fbml">\n    <head>\n         \n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n    <meta name="apple-itunes-app" content="app-id=342792525, app-argument=imdb:///?src=mdot">\n\n\n\n        <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:\'java\'};</script>\n\n<script>\n    if (typeof uet == \'function\') {\n      uet("bb", "LoadTitle", {wb: 1});\n    }\n</script>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>\n        <title>IMDb &quot;Top 1000&quot;\n(Sorted by Popularity Ascending) - IMDb</title>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>\n<script>\n    if (typeof uet == \'function\') {\n      uet("be", "LoadTitle", {wb: 1});\n    }\n</script>\
# ...

# %%
soup = BeautifulSoup(htmlcode)

# %%
#help(soup)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="app-id=342792525, app-argument=imdb:///?src=mdot" name="apple-itunes-app"/>
#   <script type="text/javascript">
#    var IMDbTimer={starttime: new Date().getTime(),pt:'java'};
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
#   </script>
#   <script>
#    (function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);
#   </script>
#   <title>
#    IMDb "Top 1000"
# (Sorted by Popularity Ascending) - IMDb
#   </title>
#   <script>
#    (function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
#   </script>
# ...

# %% [markdown]
# ## find

# %%
moviename = soup.find('h3', attrs= {'class': 'lister-item-header'})

# %%
print(moviename)
# Out:
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">1.</span>
# <a href="/title/tt12361974/">Zack Snyder's Justice League</a>
# <span class="lister-item-year text-muted unbold">(2021)</span>
# </h3>

# %% [markdown]
# ## find all

# %%
moviename  = soup.find_all('h3', attrs= {'class': 'lister-item-header'})
print(moviename)
# Out:
# [<h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">1.</span>
# <a href="/title/tt12361974/">Zack Snyder's Justice League</a>
# <span class="lister-item-year text-muted unbold">(2021)</span>
# </h3>, <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">2.</span>
# <a href="/title/tt4154796/">Avengers: Endgame</a>
# <span class="lister-item-year text-muted unbold">(2019)</span>
# </h3>, <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">3.</span>
# <a href="/title/tt5363618/">Sound of Metal</a>
# <span class="lister-item-year text-muted unbold">(2019)</span>
# </h3>, <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">4.</span>
# <a href="/title/tt1070874/">The Trial of the Chicago 7</a>
# <span class="lister-item-year text-muted unbold">(2020)</span>
# </h3>, <h3 class="lister-item-header">
# ...

# %%
year  = soup.find_all('span', attrs= {'class': 'lister-item-year text-muted unbold'})
#print(year)

# %%
ratings = soup.find_all('div', attrs={'class' : 'inline-block ratings-imdb-rating'})
#print(ratings)

# %%
duration = soup.find_all('span', attrs={'class' : 'runtime'})
#print(duration)

# %%
votes = soup.find_all('span', attrs={'name' : 'nv'})
#print(votes)

# %%
#gross = soup.find_all('p', attrs={'class' : 'sort-num_votes-visible'})
#print(votes)

# %% [markdown]
# ### retriveing required data

# %%
moviename  = soup.find_all('h3', attrs= {'class': 'lister-item-header'})
#print(moviename)
print(type(moviename))

for tag in moviename:
    print(tag.text)
# Out:
# <class 'bs4.element.ResultSet'>
#
# 1.
# Zack Snyder's Justice League
# (2021)
#
#
# 2.
# Avengers: Endgame
# (2019)
#
#
# 3.
# Sound of Metal
# (2019)
#
#
# 4.
# The Trial of the Chicago 7
# (2020)
#
#
# 5.
# Soul
# (2020)
#
#
# 6.
# Druk
# (2020)
#
#
# 7.
# The Dark Knight
# (2008)
#
#
# 8.
# Avengers: Infinity War
# (2018)
#
#
# 9.
# Watchmen
# (2009)
#
#
# 10.
# Joker
# (2019)
#
#
# 11.
# The Godfather
# (1972)
#
#
# 12.
# Once Upon a Time... in Hollywood
# (2019)
#
#
# 13.
# The Shawshank Redemption
# (1994)
#
#
# 14.
# Interstellar
# (2014)
#
#
# 15.
# Blade Runner 2049
# (2017)
#
#
# 16.
# Gisaengchung
# (2019)
#
#
# 17.
# Guardians of the Galaxy
# (2014)
#
#
# 18.
# Bohemian Rhapsody
# (2018)
#
#
# 19.
# The Gentlemen
# (2019)
#
#
# 20.
# The Lord of the Rings: The Fellowship of the Ring
# (2001)
#
#
# 21.
# Thor: Ragnarok
# (2017)
#
#
# 22.
# Harry Potter and the Sorcerer's Stone
# (2001)
#
#
# 23.
# Inception
# (2010)
#
#
# 24.
# Back to the Future
# (1985)
#
#
# 25.
# ...

# %%
ratings = soup.find_all('div', attrs={'class' : 'inline-block ratings-imdb-rating'})
#print(ratings)
for tag in ratings:
    print(tag.text)
# Out:
# 8.2
#
#
#
# 8.4
#
#
#
# 7.8
#
#
#
# 7.8
#
#
#
# 8.1
#
#
#
# 7.8
#
#
#
# 9.0
#
#
#
# 8.4
#
#
#
# 7.6
#
#
#
# 8.4
#
#
#
# 9.2
#
#
#
# 7.6
#
#
#
# 9.3
#
#
#
# 8.6
#
#
#
# 8.0
#
#
#
# 8.6
#
#
#
# 8.0
#
#
#
# 8.0
#
#
#
# 7.8
#
#
#
# 8.8
#
#
#
# 7.9
#
#
#
# 7.6
#
#
#
# 8.8
#
#
#
# 8.5
#
#
#
# 8.2
#
#
#
# 7.7
#
#
#
# 7.8
#
#
#
# 7.8
#
#
#
# 8.0
#
#
#
# 8.9
#
#
#
# 7.9
#
#
#
# 7.9
#
#
#
# 7.6
#
#
#
# 8.1
#
#
#
# 7.8
#
#
#
# 7.9
#
#
#
# 8.0
#
#
#
# 8.3
#
#
#
# 8.4
#
#
#
# 8.1
#
#
#
# 7.7
#
#
#
# 8.7
#
#
#
# 7.9
#
#
#
# 7.6
#
#
#
# 8.1
#
#
#
# 8.4
#
#
#
# 8.1
#
#
#
# 8.6
#
#
#
# 8.8
#
#
#
# 7.8
#
#
#
# 8.5
#
#
#
# 7.8
#
#
#
# 8.7
#
#
#
# 8.5
#
#
#
# 8.2
#
#
#
# 8.3
#
#
#
# 8.8
#
#
#
# 7.6
#
#
#
# 8.1
#
#
#
# 8.4
#
#
#
# 8.5
#
#
#
# 8.9
#
#
#
# 8.5
#
#
#
# 7.6
#
#
#
# 8.3
#
#
#
# 8.5
#
#
#
# 8.2
#
#
#
# 8.9
#
#
#
# 8.1
#
#
#
# 8.5
#
#
#
# 8.1
#
#
#
# 8.1
#
#
#
# 8.6
#
#
#
# 8.5
#
#
#
# 8.4
#
#
#
# 8.4
#
#
#
# 8.1
#
#
#
# 8.2
#
#
#
# 8.2
#
#
#
# 8.0
#
#
#
# 8.6
#
#
#
# 8.3
#
#
#
# 7.7
#
#
#
# ...

# %%
duration = soup.find_all('span', attrs={'class' : 'runtime'})
#print(duration)
for tag in duration:
    print(tag.text)
# Out:
# 242 min
# 181 min
# 120 min
# 129 min
# 100 min
# 117 min
# 152 min
# 149 min
# 162 min
# 122 min
# 175 min
# 161 min
# 142 min
# 169 min
# 164 min
# 132 min
# 121 min
# 134 min
# 113 min
# 178 min
# 130 min
# 152 min
# 148 min
# 116 min
# 180 min
# 136 min
# 147 min
# 194 min
# 143 min
# 154 min
# 130 min
# 118 min
# 117 min
# 149 min
# 130 min
# 108 min
# 108 min
# 119 min
# 117 min
# 127 min
# 119 min
# 146 min
# 126 min
# 102 min
# 148 min
# 164 min
# 120 min
# 118 min
# 142 min
# 162 min
# 151 min
# 135 min
# 136 min
# 155 min
# 140 min
# 153 min
# 139 min
# 136 min
# 122 min
# 117 min
# 130 min
# 195 min
# 160 min
# 101 min
# 119 min
# 110 min
# 170 min
# 201 min
# 99 min
# 137 min
# 152 min
# 117 min
# 127 min
# 106 min
# 147 min
# 165 min
# 130 min
# 138 min
# 114 min
# 131 min
# 189 min
# 102 min
# 104 min
# 153 min
# 97 min
# 169 min
# 116 min
# 115 min
# 130 min
# 113 min
# 143 min
# 107 min
# 209 min
# 170 min
# 132 min
# 129 min
# 98 min
# 106 min
# 169 min
# 122 min

# %%
votes = soup.find_all('span', attrs={'name' : 'nv'})
#print(votes)
for tag in votes:
    print(tag.text)
# Out:
# 240,154
# 848,462
# $858.37M
# 53,182
# 122,611
# 214,519
# 54,834
# 2,334,607
# $534.86M
# 859,874
# $678.82M
# 509,262
# $107.51M
# 974,034
# $335.45M
# 1,641,981
# $134.97M
# 569,169
# $142.50M
# 2,371,111
# $28.34M
# 1,538,570
# $188.02M
# 471,644
# $92.05M
# 584,694
# $53.37M
# 1,055,251
# $333.18M
# 460,750
# $216.43M
# 254,238
# 1,679,952
# $315.54M
# 602,746
# $315.06M
# 667,682
# $317.58M
# 2,094,139
# $292.58M
# 1,071,587
# $210.61M
# 1,209,209
# $116.90M
# 746,957
# $259.77M
# 675,795
# $408.08M
# 1,057,500
# $659.33M
# 1,273,095
# $623.28M
# 1,847,489
# $107.93M
# 476,299
# $165.36M
# 194,424
# $5.88M
# 738,758
# $210.61M
# 873,473
# $167.77M
# 128,679
# $56.51M
# 310,717
# $0.35M
# 913,565
# $363.07M
# 447,645
# $159.23M
# 796,492
# $78.90M
# 877,228
# $402.45M
# 489,458
# $324.59M
# 1,033,829
# $46.84M
# 950,931
# $318.41M
# 167,933
# $7.99M
# 579,312
# $18.35M
# 1,532,837
# $448.14M
# 893,308
# $154.06M
# 1,287,162
# $130.74M
# 1,833,416
# $330.25M
# 1,127,528
# ...

# %%
year = soup.find_all('span', attrs={'class' : 'lister-item-year text-muted unbold'})
#print(vg )
for tag in year:
    print(tag.text)
# Out:
# (2021)
# (2019)
# (2019)
# (2020)
# (2020)
# (2020)
# (2008)
# (2018)
# (2009)
# (2019)
# (1972)
# (2019)
# (1994)
# (2014)
# (2017)
# (2019)
# (2014)
# (2018)
# (2019)
# (2001)
# (2017)
# (2001)
# (2010)
# (1985)
# (2013)
# (2014)
# (2016)
# (1997)
# (2012)
# (1994)
# (2019)
# (2016)
# (2006)
# (2014)
# (1993)
# (2019)
# (2016)
# (2019)
# (1979)
# (1993)
# (2018)
# (1990)
# (2008)
# (1993)
# (2007)
# (2012)
# (2015)
# (1991)
# (1994)
# (2009)
# (2006)
# (2019)
# (1999)
# (2000)
# (2005)
# (2009)
# (1999)
# (2017)
# (2007)
# (2018)
# (2006)
# (1993)
# (2020)
# (2000)
# (1941)
# (1994)
# (1995)
# (2003)
# (2014)
# (1991)
# (2019)
# (1982)
# (1995)
# (2014)
# (1979)
# (2012)
# (2011)
# (2010)
# (1976)
# (1966)
# (1999)
# (2000)
# (I) (2017)
# (2013)
# (1985)
# (2012)
# (II) (2016)
# (1981)
# (2018)
# (I) (2017)
# (2003)
# (I) (2016)
# (2019)
# (1983)
# (2017)
# (2005)
# (1987)
# (2017)
# (1998)
# (1999)

# %%
# gross = soup.find_all('p', attrs={'class' : 'sort-num_votes-visible'})
# print(gross)
# for tag in gross:
#     print(tag.text)

# %% [markdown]
# ### Code for Web Scrapping

# %%
title = []
rating = []
duration = []
votes = []
year = []
#gross = []
for i in range(1,11):
    url = 'https://www.imdb.com/search/title/?count=100&groups=top_1000&sort=user_rating%27'
    page = requests.get(url)
    htmlCode = page.text
    
    soup = BeautifulSoup(htmlCode)
    
    for x in soup.find_all('div', attrs={'class' : 'lister-item mode-advanced'}):

                   
        # title    
        titles = x.find('h3', attrs= {'class': 'lister-item-header'})
        if titles is None:
            title.append(np.NaN)
        else:
            title.append(titles.text)

        # ratings
        ratings = x.find('div', attrs={'class' : 'inline-block ratings-imdb-rating'})
        if ratings is None:
            rating.append(np.NaN)
        else:
            rating.append(ratings.text)

            
        # duration
        durations = x.find('span', attrs={'class' : 'runtime'})
        if durations is None:
            duration.append(np.NaN)
        else:
            duration.append(durations.text)

        
        
        #votes
        vote = x.find('span', attrs={'name' : 'nv'})
        if vote is None:
            votes.append(np.NaN)
        else:
            votes.append(vote.text)
            
        #year
        years = x.find('span', attrs={'class' : 'lister-item-year text-muted unbold'})
        if years is None:
            year.append(np.NaN)
        else:
            year.append(years.text)
            
        #gross
#         gros = x.find('p', attrs={'class' : 'sort-num_votes-visible'}
#         if gros is None:
#             gross.append(np.NaN)
#         else:
#             gross.append(years.text)

# %%
print(len(title))
print(len(rating))
print(len(duration))
print(len(votes))
print(len(year))
# Out:
# 1000
# 1000
# 1000
# 1000
# 1000

# %% [markdown]
# ### Create a DataFrame and save it in CSV file

# %%
df = pd.DataFrame({'Title' : title, 'Ratings' : rating, 'Duration' : duration, 'Votes' : votes ,'Year': year})

# %%
df.head()
# Out:
#                                           Title    Ratings Duration    Votes  \
# 0  \n1.\nZack Snyder's Justice League\n(2021)\n  \n\n8.2\n  242 min  240,154
# 1             \n2.\nAvengers: Endgame\n(2019)\n  \n\n8.4\n  181 min  848,462
# 2                \n3.\nSound of Metal\n(2019)\n  \n\n7.8\n  120 min   53,182
# 3    \n4.\nThe Trial of the Chicago 7\n(2020)\n  \n\n7.8\n  129 min  122,611
# 4                          \n5.\nSoul\n(2020)\n  \n\n8.1\n  100 min  214,519
#
#      Year
# 0  (2021)
# 1  (2019)
# 2  (2019)
# 3  (2020)
# 4  (2020)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     1000 non-null   object
#  1   Ratings   1000 non-null   object
#  2   Duration  1000 non-null   object
#  3   Votes     1000 non-null   object
#  4   Year      1000 non-null   object
# dtypes: object(5)
# memory usage: 39.2+ KB

# %%
df.to_csv('imdb1000.csv', index = False)

# %% [markdown]
# ### Extracting the Details using Regex

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("imdb1000.csv")

df.head(10)
# Out:
#                                           Title  Ratings Duration      Votes  \
# 0  \n1.\nZack Snyder's Justice League\n(2021)\n      8.2  242 min    240,154
# 1             \n2.\nAvengers: Endgame\n(2019)\n      8.4  181 min    848,462
# 2                \n3.\nSound of Metal\n(2019)\n      7.8  120 min     53,182
# 3    \n4.\nThe Trial of the Chicago 7\n(2020)\n      7.8  129 min    122,611
# 4                          \n5.\nSoul\n(2020)\n      8.1  100 min    214,519
# 5                          \n6.\nDruk\n(2020)\n      7.8  117 min     54,834
# 6               \n7.\nThe Dark Knight\n(2008)\n      9.0  152 min  2,334,607
# 7        \n8.\nAvengers: Infinity War\n(2018)\n      8.4  149 min    859,874
# 8                      \n9.\nWatchmen\n(2009)\n      7.6  162 min    509,262
# 9                        \n10.\nJoker\n(2019)\n      8.4  122 min    974,034
#
#      Year
# 0  (2021)
# 1  (2019)
# 2  (2019)
# 3  (2020)
# 4  (2020)
# 5  (2020)
# 6  (2008)
# 7  (2018)
# 8  (2009)
# ...

# %%
import re

# %%
regex = r'[^\n\d,().]+'

df['movie name'] = df['Title'].apply(lambda x : re.findall(regex, x))

# %%
df.head()
# Out:
#                                           Title  Ratings Duration    Votes  \
# 0  \n1.\nZack Snyder's Justice League\n(2021)\n      8.2  242 min  240,154
# 1             \n2.\nAvengers: Endgame\n(2019)\n      8.4  181 min  848,462
# 2                \n3.\nSound of Metal\n(2019)\n      7.8  120 min   53,182
# 3    \n4.\nThe Trial of the Chicago 7\n(2020)\n      7.8  129 min  122,611
# 4                          \n5.\nSoul\n(2020)\n      8.1  100 min  214,519
#
#      Year                      movie name
# 0  (2021)  [Zack Snyder's Justice League]
# 1  (2019)             [Avengers: Endgame]
# 2  (2019)                [Sound of Metal]
# 3  (2020)     [The Trial of the Chicago ]
# 4  (2020)                          [Soul]

# %%
regex =  r'[^()]+'

df['year'] = df['Year'].apply(lambda x : re.findall(regex, x))

# %%
df.head()
# Out:
#                                           Title  Ratings Duration    Votes  \
# 0  \n1.\nZack Snyder's Justice League\n(2021)\n      8.2  242 min  240,154
# 1             \n2.\nAvengers: Endgame\n(2019)\n      8.4  181 min  848,462
# 2                \n3.\nSound of Metal\n(2019)\n      7.8  120 min   53,182
# 3    \n4.\nThe Trial of the Chicago 7\n(2020)\n      7.8  129 min  122,611
# 4                          \n5.\nSoul\n(2020)\n      8.1  100 min  214,519
#
#      Year                      movie name    year
# 0  (2021)  [Zack Snyder's Justice League]  [2021]
# 1  (2019)             [Avengers: Endgame]  [2019]
# 2  (2019)                [Sound of Metal]  [2019]
# 3  (2020)     [The Trial of the Chicago ]  [2020]
# 4  (2020)                          [Soul]  [2020]

# %%
df = df.drop(["Title","Year"], axis=1)

# %%
df.head()
# Out:
#    Ratings Duration    Votes                      movie name    year
# 0      8.2  242 min  240,154  [Zack Snyder's Justice League]  [2021]
# 1      8.4  181 min  848,462             [Avengers: Endgame]  [2019]
# 2      7.8  120 min   53,182                [Sound of Metal]  [2019]
# 3      7.8  129 min  122,611     [The Trial of the Chicago ]  [2020]
# 4      8.1  100 min  214,519                          [Soul]  [2020]

# %%
#df.to_excel(r'C:\Users\satis\Desktop\imdb.xlsx', index = False)

# %% [markdown]
# ## cleaning the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Ratings     1000 non-null   float64
#  1   Duration    1000 non-null   object
#  2   Votes       1000 non-null   object
#  3   movie name  1000 non-null   object
#  4   year        1000 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 39.2+ KB

# %%
# Missing Values

df.isnull().sum()# Missing Values

df.isnull().sum()
# Out:
# Ratings       0
# Duration      0
# Votes         0
# movie name    0
# year          0
# dtype: int64

# %%
print(df['movie name'][0])

print(type(df['movie name'][0]))
# Out:
# ["Zack Snyder's Justice League"]
# <class 'list'>

# %%
print(''.join(df['movie name'][0]))
print(type(''.join(df['movie name'][0])))
# Out:
# Zack Snyder's Justice League
# <class 'str'>

# %%
df['movie name'] = df['movie name'].apply(lambda x : ''.join(x))

# %%
print(df['year'][0])

print(type(df['year'][0]))
# Out:
# ['2021']
# <class 'list'>

# %%
print(''.join(df['year'][0]))
print(type(''.join(df['year'][0])))
# Out:
# 2021
# <class 'str'>

# %%
df['year'] = df['year'].apply(lambda x : ''.join(x))

# %%
df
# Out:
#      Ratings Duration      Votes                    movie name  year
# 0        8.2  242 min    240,154  Zack Snyder's Justice League  2021
# 1        8.4  181 min    848,462             Avengers: Endgame  2019
# 2        7.8  120 min     53,182                Sound of Metal  2019
# 3        7.8  129 min    122,611     The Trial of the Chicago   2020
# 4        8.1  100 min    214,519                          Soul  2020
# ..       ...      ...        ...                           ...   ...
# 995      7.8  129 min    262,917             Pride & Prejudice  2005
# 996      8.0   98 min    396,665            The Princess Bride  1987
# 997      7.8  106 min    565,320                       Dunkirk  2017
# 998      8.6  169 min  1,249,781           Saving Private Ryan  1998
# 999      8.3  122 min  1,078,579               American Beauty  1999
#
# [1000 rows x 5 columns]

# %%
df.to_excel(r'C:\Users\satis\Desktop\imdb.xlsx', index = False)

# %%
df.to_csv('cleandImdb1000.csv', index = False)
